# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv("fruits.csv")
data
# Out:
#     Color  Diameter (cm)   Fruit
# 0     Red              3   Apple
# 1     Red              3   Apple
# 2  Yellow              1   Lemon
# 3  Yellow              1   Lemon
# 4  Yellow              3   Lemon
# 5  Yellow              3  Orange
# 6  Orange              2  Orange
# 7  Orange              2  Orange

# %%
data = pd.get_dummies(data, columns = ['Color'],drop_first = True)
data
# Out:
#    Diameter (cm)   Fruit  Color_Red  Color_Yellow
# 0              3   Apple       True         False
# 1              3   Apple       True         False
# 2              1   Lemon      False          True
# 3              1   Lemon      False          True
# 4              3   Lemon      False          True
# 5              3  Orange      False          True
# 6              2  Orange      False         False
# 7              2  Orange      False         False

# %%
uniq = data['Fruit'].unique()
X = data[['Diameter (cm)','Color_Red','Color_Yellow']]
y = data[['Fruit']]

# Train a decision tree classifier
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=uniq)
plt.show()

# %%
# Testing
x_test = pd.DataFrame(columns = X.columns)
x_test.loc[0] = [2,0,1] # diame
x_test
# Out:
#    Diameter (cm)  Color_Red  Color_Yellow
# 0              2          0             1

# %%
y_pred = clf.predict(x_test)
y_pred
# Out:
# array(['Lemon'], dtype=object)

# %%
data = pd.read_csv("diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Outcome
# 0     0.627   50        1
# 1     0.351   31        0
# 2     0.672   32        1
# 3     0.167   21        0
# 4     2.288   33        1

# %%
col = 'Outcome'
x_ind = data.loc[:, data.columns!=col] 
y_dep = data[col]

# %%
X_train, X_test, y_train, y_test = tts((x_ind),(y_dep),test_size = 0.2, random_state= 42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# Create Decision Tree classifer object
clf = DecisionTreeClassifier(max_depth = 8, min_samples_split= 40)


# Train Decision Tree Classifer
clf.fit(X_train_scaled,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion)    
print("Accuracy:", round(accuracy,2))
print("Precision:", round(precision,2))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))

plt.figure(figsize=(20,10))
plot_tree(clf, filled=True, feature_names=x_ind.columns, class_names=['0','1'], fontsize = 14)
plt.savefig("decision_tree.png")
plt.show()
# Out:
# Confusion Matrix:
# [[72 27]
#  [13 42]]
# Accuracy: 0.74
# Precision: 0.61
# Recall: 0.76
# F1 Score: 0.68

# %%
# Create Decision Tree classifer object
clf = RandomForestClassifier()


# Train Decision Tree Classifer
clf.fit(X_train_scaled,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion)    
print("Accuracy:", round(accuracy,2))
print("Precision:", round(precision,2))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Confusion Matrix:
# [[80 19]
#  [19 36]]
# Accuracy: 0.75
# Precision: 0.65
# Recall: 0.65
# F1 Score: 0.65
